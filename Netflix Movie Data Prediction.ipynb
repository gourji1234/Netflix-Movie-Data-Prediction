# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("E:\\AI Python\\Netflix dataset\\imdb.csv")

# %%
df.head()
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  13,27,188
# 1  Drama, Mystery, Thriller     7.5   3,14,321
# 2      Comedy, Crime, Drama     8.0   3,19,342
# 3    Drama, Mystery, Sci-Fi     8.7   6,36,319
# 4      Action, Crime, Drama     8.2   5,29,086

# %%
df.iloc()

# %%
df.describe()
# Out:
#        lister-item-index     rating
# count          79.000000  79.000000
# mean           40.468354   7.717722
# std            23.384652   0.713022
# min             1.000000   5.900000
# 25%            20.500000   7.200000
# 50%            40.000000   7.800000
# 75%            60.500000   8.200000
# max            80.000000   8.800000

# %%
df.tail()
# Out:
#     lister-item-index lister-item-header certificate runtime  \
# 75               76.0    F Is for Family          15  30 min
# 76               77.0          The Ranch          15  30 min
# 77               78.0    American Vandal          15  34 min
# 78               79.0         Dead to Me          15  30 min
# 79               80.0          Quicksand          18  45 min
#
#                        genre  rating   votes
# 75  Animation, Comedy, Drama     8.0  41,074
# 76    Comedy, Drama, Western     7.5  42,401
# 77      Comedy, Crime, Drama     8.1  32,985
# 78      Comedy, Crime, Drama     7.9  99,440
# 79     Crime, Drama, Mystery     7.4  25,507

# %%
df.sample()
# Out:
#     lister-item-index lister-item-header certificate runtime          genre  \
# 60               61.0     Master of None          15  30 min  Comedy, Drama
#
#     rating   votes
# 60     8.2  76,143

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lister-item-index   79 non-null     float64
#  1   lister-item-header  79 non-null     object
#  2   certificate         79 non-null     object
#  3   runtime             79 non-null     object
#  4   genre               79 non-null     object
#  5   rating              79 non-null     float64
#  6   votes               79 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.5+ KB

# %%
df.isnull()
# Out:
#     lister-item-index  lister-item-header  certificate  runtime  genre  \
# 0               False               False        False    False  False
# 1               False               False        False    False  False
# 2               False               False        False    False  False
# 3               False               False        False    False  False
# 4               False               False        False    False  False
# ..                ...                 ...          ...      ...    ...
# 75              False               False        False    False  False
# 76              False               False        False    False  False
# 77              False               False        False    False  False
# 78              False               False        False    False  False
# 79              False               False        False    False  False
#
#     rating  votes
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# ...

# %%
df.nunique()
# Out:
# lister-item-index     79
# lister-item-header    79
# certificate            4
# runtime               27
# genre                 44
# rating                27
# votes                 79
# dtype: int64

# %%
df.min()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20460\3962516015.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# lister-item-index    1.0
# rating               5.9
# dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#Decision Clasification

# %%
dataset=pd.read_csv("E:\\AI Python\\Netflix dataset\\imdb.csv")

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lister-item-index   79 non-null     float64
#  1   lister-item-header  79 non-null     object
#  2   certificate         79 non-null     object
#  3   runtime             79 non-null     object
#  4   genre               79 non-null     object
#  5   rating              79 non-null     float64
#  6   votes               79 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.5+ KB

# %%
dataset['runtime'].unique()
# Out:
# array(['60 min', '59 min', '4,393 min', '50 min', '56 min', '25 min',
#        '45 min', '55 min', '30 min', '1,164 min', '49 min', '572 min',
#        '26 min', nan, '58 min', '386 min', '370 min', '23 min', '15 min',
#        '356 min', '63 min', '27 min', '35 min', '51 min', '52 min',
#        '22 min', '46 min', '34 min'], dtype=object)

# %%
print(X)
# Out:
# [[1.0 'Stranger Things' '15' '60 min' 'Drama, Fantasy, Horror' 8.7]
#  [2.0 '13 Reasons Why' '18' '60 min' 'Drama, Mystery, Thriller' 7.5]
#  [3.0 'Orange Is the New Black' '18' '59 min' 'Comedy, Crime, Drama' 8.0]
#  [4.0 'Black Mirror' '18' '60 min' 'Drama, Mystery, Sci-Fi' 8.7]
#  [5.0 'Money Heist' '15' '60 min' 'Action, Crime, Drama' 8.2]
#  [6.0 'Lucifer' '15' '4,393 min' 'Crime, Drama, Fantasy' 8.1]
#  [7.0 'Narcos' '15' '50 min' 'Biography, Crime, Drama' 8.8]
#  [8.0 'Daredevil' '15' '60 min' 'Action, Crime, Drama' 8.6]
#  [9.0 'Sense8' '15' '60 min' 'Drama, Mystery, Sci-Fi' 8.2]
#  [10.0 'Jessica Jones' '15' '56 min' 'Action, Crime, Drama' 7.9]
#  [11.0 'House of Cards' '18' '50 min' 'Drama' 8.6]
#  [12.0 'The End of the F***ing World' '15' '25 min'
#   'Adventure, Comedy, Crime' 8.0]
#  [13.0 'Dark' '15' '60 min' 'Crime, Drama, Mystery' 8.7]
#  [14.0 'Sex Education' '18' '60 min' 'Comedy, Drama, Romance' 8.3]
#  [15.0 'Elite' '15' '60 min' 'Crime, Drama, Thriller' 7.2]
# ...

# %%
#Polinomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %%
dataset
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  13,27,188
# 1   Drama, Mystery, Thriller     7.5   3,14,321
# ...

# %%
X
# Out:
# array([['Stranger Things', '15', '60 min', 'Drama, Fantasy, Horror', 8.7],
#        ['13 Reasons Why', '18', '60 min', 'Drama, Mystery, Thriller',
#         7.5],
#        ['Orange Is the New Black', '18', '59 min',
#         'Comedy, Crime, Drama', 8.0],
#        ['Black Mirror', '18', '60 min', 'Drama, Mystery, Sci-Fi', 8.7],
#        ['Money Heist', '15', '60 min', 'Action, Crime, Drama', 8.2],
#        ['Lucifer', '15', '4,393 min', 'Crime, Drama, Fantasy', 8.1],
#        ['Narcos', '15', '50 min', 'Biography, Crime, Drama', 8.8],
#        ['Daredevil', '15', '60 min', 'Action, Crime, Drama', 8.6],
#        ['Sense8', '15', '60 min', 'Drama, Mystery, Sci-Fi', 8.2],
#        ['Jessica Jones', '15', '56 min', 'Action, Crime, Drama', 7.9],
#        ['House of Cards', '18', '50 min', 'Drama', 8.6],
#        ['The End of the F***ing World', '15', '25 min',
#         'Adventure, Comedy, Crime', 8.0],
#        ['Dark', '15', '60 min', 'Crime, Drama, Mystery', 8.7],
# ...

# %%
dataset
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  13,27,188
# 1   Drama, Mystery, Thriller     7.5   3,14,321
# ...

# %%
X
# Out:
# array([[1.0, 'Stranger Things', '15', '60 min', 'Drama, Fantasy, Horror',
#         8.7],
#        [2.0, '13 Reasons Why', '18', '60 min',
#         'Drama, Mystery, Thriller', 7.5],
#        [3.0, 'Orange Is the New Black', '18', '59 min',
#         'Comedy, Crime, Drama', 8.0],
#        [4.0, 'Black Mirror', '18', '60 min', 'Drama, Mystery, Sci-Fi',
#         8.7],
#        [5.0, 'Money Heist', '15', '60 min', 'Action, Crime, Drama', 8.2],
#        [6.0, 'Lucifer', '15', '4,393 min', 'Crime, Drama, Fantasy', 8.1],
#        [7.0, 'Narcos', '15', '50 min', 'Biography, Crime, Drama', 8.8],
#        [8.0, 'Daredevil', '15', '60 min', 'Action, Crime, Drama', 8.6],
#        [9.0, 'Sense8', '15', '60 min', 'Drama, Mystery, Sci-Fi', 8.2],
#        [10.0, 'Jessica Jones', '15', '56 min', 'Action, Crime, Drama',
#         7.9],
#        [11.0, 'House of Cards', '18', '50 min', 'Drama', 8.6],
#        [12.0, 'The End of the F***ing World', '15', '25 min',
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 5)
X_poly = poly_reg.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 3
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 poly_reg = PolynomialFeatures(degree = 5)
# ----> 3 X_poly = poly_reg.fit_transform(X)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# ...

# %%
#Random_Forest Classification

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
print(X_train)
# Out:
# [[nan nan nan nan nan]
#  ['Lost in Space' '12' '60 min' 'Adventure, Drama, Family' 7.3]
#  ['Everything Sucks!' '15' '30 min' 'Comedy, Drama' 7.4]
#  ['Quicksand' '18' '45 min' 'Crime, Drama, Mystery' 7.4]
#  ['Greenhouse Academy' 'PG' '25 min' 'Adventure, Comedy, Drama' 6.6]
#  ['The OA' '15' '60 min' 'Drama, Fantasy, Mystery' 7.8]
#  ['Master of None' '15' '30 min' 'Comedy, Drama' 8.2]
#  ['Narcos Mexico' '15' '60 min' 'Crime, Drama' 8.0]
#  ['Narcos' '15' '50 min' 'Biography, Crime, Drama' 8.8]
#  ["RuPaul's Drag Race" '15' '63 min' 'Game-Show, Reality-TV' 8.5]
#  ['Hemlock Grove' '15' '46 min' 'Drama, Fantasy, Horror' 7.0]
#  ['Money Heist' '15' '60 min' 'Action, Crime, Drama' 8.2]
#  ['Santa Clarita Diet' '15' '30 min' 'Comedy, Horror' 7.8]
#  ['Dear White People' '15' '30 min' 'Comedy, Drama' 6.4]
#  ['Insatiable' '15' '45 min' 'Comedy, Drama, Thriller' 6.5]
#  ['The End of the F***ing World' '15' '25 min' 'Adventure, Comedy, Crime'
#   8.0]
# ...

# %%
print(X_test)
# Out:
# [['Marco Polo' '15' '60 min' 'Action, Adventure, Drama' 8.0]
#  ['A Series of Unfortunate Events' 'PG' '1,164 min'
#   'Adventure, Comedy, Drama' 7.7]
#  ['3%' '15' '49 min' 'Action, Drama, Sci-Fi' 7.3]
#  ['American Vandal' '15' '34 min' 'Comedy, Crime, Drama' 8.1]
#  ['Maniac' '18' '386 min' 'Comedy, Drama, Sci-Fi' 7.7]
#  ['Friends from College' '18' '30 min' 'Comedy, Drama' 6.9]
#  ['GLOW' '18' '35 min' 'Comedy, Drama, Sport' 8.0]
#  ['Gypsy' '15' '51 min' 'Drama, Thriller' 6.7]
#  ['Castlevania' '15' '23 min' 'Animation, Action, Adventure' 8.3]
#  ['The Get Down' '15' '52 min' 'Drama, Music, Musical' 8.2]
#  ['Unbreakable Kimmy Schmidt' '12' '30 min' 'Comedy' 7.6]
#  ['The Hookup Plan' '15' '27 min' 'Comedy, Romance' 7.1]
#  ['Orange Is the New Black' '18' '59 min' 'Comedy, Crime, Drama' 8.0]
#  ['Arrested Development' '15' '22 min' 'Comedy' 8.7]
#  ['Love, Death & Robots' '18' '15 min' 'Animation, Short, Action' 8.4]
# ...

# %%
print(y_train)
# Out:
# [nan '1,05,388' '23,120' '25,507' '6,921' '1,15,239' '76,143' '92,447'
#  '4,67,909' '23,189' '42,524' '5,29,086' '75,813' '26,364' '32,495'
#  '2,18,483' '33,053' '89,033' '5,29,463' '1,87,859' '1,64,641' '45,854'
#  '3,14,321' '2,86,535' '41,074' '90,237' '51,704' '2,73,779' '3,33,075'
#  '19,427' '41,355' '1,86,993' '2,63,516' '13,27,188' '99,440' '2,97,650'
#  '3,54,155' '63,928' '1,07,853' '56,789' '1,39,364' '16,830' '1,62,528'
#  '3,48,817' '1,16,048' '3,44,631' '44,543' '13,083' '9,906' '29,332'
#  '4,40,321' '36,866' '19,687' '1,39,241' '2,26,187' '42,401' '1,02,505'
#  '18,238' '1,06,602' '36,504']

# %%
print(y_test)
# Out:
# ['78,306' '66,482' '28,008' '32,985' '86,275' '23,324' '50,376' '18,683'
#  '79,792' '23,633' '78,450' '5,910' '3,19,342' '3,23,189' '1,95,422'
#  '72,503' '6,36,319' '1,03,009' '4,72,940' '2,55,352']

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv("E:\\AI Python\\Netflix dataset\\imdb.csv")
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
dataset
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  13,27,188
# 1   Drama, Mystery, Thriller     7.5   3,14,321
# ...

# %%
y
# Out:
# array(['13,27,188', '3,14,321', '3,19,342', '6,36,319', '5,29,086',
#        '3,54,155', '4,67,909', '4,72,940', '1,62,528', '2,26,187',
#        '5,29,463', '2,18,483', '4,40,321', '3,48,817', '90,237',
#        '2,97,650', '1,07,853', '1,15,239', '2,63,516', '2,73,779',
#        '1,39,364', '1,39,241', '1,03,009', '89,033', '41,355', '1,16,048',
#        '2,55,352', '66,482', '32,495', '3,33,075', '28,008', '1,87,859',
#        '2,86,535', '75,813', '72,503', '1,86,993', '19,687', '3,44,631',
#        '1,05,388', '13,083', '78,450', '23,120', nan, '1,64,641',
#        '36,504', '86,275', '44,543', '1,06,602', '79,792', '19,427',
#        '78,306', '56,789', '1,95,422', '26,364', '51,704', '6,921',
#        '23,189', '33,053', '29,332', '63,928', '76,143', '45,854',
#        '92,447', '5,910', '18,238', '9,906', '50,376', '1,02,505',
#        '18,683', '23,633', '36,866', '23,324', '3,23,189', '42,524',
#        '16,830', '41,074', '42,401', '32,985', '99,440', '25,507'],
# ...

# %%
#Simple linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
 
dataset = pd.read_csv("E:\\AI Python\\Netflix dataset\\imdb.csv")
dataset.head()
# Out:
#    lister-item-index       lister-item-header certificate runtime  \
# 0                1.0          Stranger Things          15  60 min
# 1                2.0           13 Reasons Why          18  60 min
# 2                3.0  Orange Is the New Black          18  59 min
# 3                4.0             Black Mirror          18  60 min
# 4                5.0              Money Heist          15  60 min
#
#                       genre  rating      votes
# 0    Drama, Fantasy, Horror     8.7  13,27,188
# 1  Drama, Mystery, Thriller     7.5   3,14,321
# 2      Comedy, Crime, Drama     8.0   3,19,342
# 3    Drama, Mystery, Sci-Fi     8.7   6,36,319
# 4      Action, Crime, Drama     8.2   5,29,086

# %%
dataset
# Out:
#     lister-item-index       lister-item-header certificate runtime  \
# 0                 1.0          Stranger Things          15  60 min
# 1                 2.0           13 Reasons Why          18  60 min
# 2                 3.0  Orange Is the New Black          18  59 min
# 3                 4.0             Black Mirror          18  60 min
# 4                 5.0              Money Heist          15  60 min
# ..                ...                      ...         ...     ...
# 75               76.0          F Is for Family          15  30 min
# 76               77.0                The Ranch          15  30 min
# 77               78.0          American Vandal          15  34 min
# 78               79.0               Dead to Me          15  30 min
# 79               80.0                Quicksand          18  45 min
#
#                        genre  rating      votes
# 0     Drama, Fantasy, Horror     8.7  13,27,188
# 1   Drama, Mystery, Thriller     7.5   3,14,321
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lister-item-index   79 non-null     float64
#  1   lister-item-header  79 non-null     object
#  2   certificate         79 non-null     object
#  3   runtime             79 non-null     object
#  4   genre               79 non-null     object
#  5   rating              79 non-null     float64
#  6   votes               79 non-null     object
# dtypes: float64(2), object(5)
# memory usage: 4.5+ KB

# %%
dataset['certificate'].unique()
# Out:
# array(['15', '18', '12', 'PG', nan], dtype=object)

# %%
X = dataset.iloc[:,:-1].values  #independent variable array
y = dataset.iloc[:,1].values  #dependent variable vector

# %%
#Pandas
